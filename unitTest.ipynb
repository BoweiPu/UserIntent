# %%
from model.infer_cot import infer_cot
model=infer_cot()

# %%
import json


data_info=json.load(open('/home/pubw/proj/LLaMA-Factory/data/mire/train_modified.json'))
input_data=[data_info[586]]

# %%
input_data

# %%
model(input_data)

# %%
from PIL import Image
from IPython.display import display
input_data=[data_info[266]]
# Open the image
img_path = input_data[0]['image'][0]
img = Image.open(img_path)

# Display the image in Jupyter Notebook
display(img)

# %%
from dataset import create_data_loader,CustomDataset
import json
json_file=json.load(open('/home/pubw/proj/LLaMA-Factory/data/mire/train_modified.json'))
dataloader=create_data_loader(json_file,'')

# %%
dataset = CustomDataset(json_file,'')

# %%
dataset.__getitem__(1)

# %%
for item in dataloader:
    print(item)
    break

# %%
import cv2
import numpy as np
def mask_and_fill_with_external_values(image_path, polygons, output_path="output.jpg"):
    """
    使用多边形区域外部值填充多边形区域。
    
    :param image_path: 输入图片路径。
    :param polygons: 多边形坐标列表，例如 [[[x1, y1], [x2, y2], ...], ...]
    :param output_path: 输出图片路径。
    """
    # 1. 读取图片
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError("无法加载图片，请检查路径是否正确。")
    
    # 2. 创建掩膜
    mask = np.zeros(image.shape[:2], dtype=np.uint8)
    for polygon_coords in polygons:
        polygon_coords = np.array([polygon_coords], dtype=np.int32)
        cv2.fillPoly(mask, polygon_coords, 255)
    
    # 3. 使用掩膜外部值进行填充
    result = cv2.inpaint(image, mask, inpaintRadius=3, flags=cv2.INPAINT_TELEA)
    
    # 4. 保存结果
    cv2.imwrite(output_path, result)
    return result

# %%
from builder.ocr_builder import build_ocr
ocr_model=build_ocr()

# %%
import json
import os
from PIL import Image

from tqdm import tqdm
from builder.ocr_builder import build_ocr
import torch
import logging
import jieba

# 设置基本配置，level=logging.WARNING表示只记录warning及更高级别的日志
logging.getLogger('ppocr').setLevel(logging.ERROR)
train_json="/home/pubw/datasets/www25/train/train_task2.json"
image_path="/home/pubw/datasets/www25/train/images/"
save_path="/home/pubw/proj/UserIntent/masked/remain_key/"
key_words=json.load(open('/home/pubw/proj/UserIntent/utils/task2_text_frequency_top20.json'))
os.makedirs(save_path, exist_ok=True)
json_file=json.load(open(train_json))


image_embed_list=[]
image_info_list=[]
for item in tqdm(json_file):
    image_list=[image_path+item_path for item_path in item['image']]
    input_image_list=[]
    #for image_item in image_list:
        #input_image_list.append(Image.open(image_path+image_item).convert('RGB'))
    
    for img in image_list:
        mask_list=[]
        ocr_res=ocr_model.ocr(img, cls=False)[0]
        if ocr_res is None:
            continue
        for ocr_tiem in ocr_res:
            #print(ocr_tiem)
            #print(f"bbox:{ocr_tiem[0]},res:{ocr_tiem[1]}")
            #print(ocr_tiem[1])
            #print(key_words[item['output']])
            #print(jieba.lcut(ocr_tiem[1][0]))
            if any(keyword in jieba.lcut(ocr_tiem[1][0]) for keyword in key_words[item['output']]):
                continue
            #print(ocr_tiem[1])
            mask_list.append(ocr_tiem[0])
        mask_and_fill_with_external_values(img,mask_list,save_path+img.split("/")[-1])
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 41
#      34     continue
#      35 for ocr_tiem in ocr_res:
#      36     #print(ocr_tiem)
#      37     #print(f"bbox:{ocr_tiem[0]},res:{ocr_tiem[1]}")
#      38     #print(ocr_tiem[1])
#      39     #print(key_words[item['output']])
#      40     #print(jieba.lcut(ocr_tiem[1][0]))
# ---> 41     if any(keyword in jieba.lcut(ocr_tiem[1][0]) for keyword in key_words[item['output']]):
#      42         continue
#      43     #print(ocr_tiem[1])
#
# KeyError: 'output'

# %%
import json
import os
from PIL import Image

from tqdm import tqdm
from builder.ocr_builder import build_ocr
import torch
import logging
import jieba

# 设置基本配置，level=logging.WARNING表示只记录warning及更高级别的日志
logging.getLogger('ppocr').setLevel(logging.ERROR)
train_json="/home/pubw/datasets/www25/test1/test1_task2.json"
image_path="/home/pubw/datasets/www25/test1/images/"
save_path="/home/pubw/proj/UserIntent/masked/remain_key_test/"
key_words=json.load(open('/home/pubw/proj/UserIntent/utils/task2_text_frequency_top20.json'))
key_words = [item for sublist in list(key_words.values()) for item in sublist]
os.makedirs(save_path, exist_ok=True)
json_file=json.load(open(train_json))


image_embed_list=[]
image_info_list=[]
for item in tqdm(json_file):
    image_list=[image_path+item_path for item_path in item['image']]
    input_image_list=[]
    #for image_item in image_list:
        #input_image_list.append(Image.open(image_path+image_item).convert('RGB'))
    if os.path.exists(save_path+img.split("/")[-1]):
        continue
    for img in image_list:
        mask_list=[]
        ocr_res=ocr_model.ocr(img, cls=False)[0]
        if ocr_res is None:
            continue
        for ocr_tiem in ocr_res:
            #print(ocr_tiem)
            #print(f"bbox:{ocr_tiem[0]},res:{ocr_tiem[1]}")
            #print(ocr_tiem[1])
            #print(key_words[item['output']])
            #print(jieba.lcut(ocr_tiem[1][0]))
            if any(keyword in jieba.lcut(ocr_tiem[1][0]) for keyword in key_words):
                continue
            #print(ocr_tiem[1])
            mask_list.append(ocr_tiem[0])
        mask_and_fill_with_external_values(img,mask_list,save_path+img.split("/")[-1])
# Out:
#  20%|█▉        | 994/5000 [07:45<31:16,  2.14it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 32
#      30 for img in image_list:
#      31     mask_list=[]
# ---> 32     ocr_res=ocr_model.ocr(img, cls=False)[0]
#      33     if ocr_res is None:
#      34         continue
#
# File /opt/conda/envs/qwen/lib/python3.9/site-packages/paddleocr/paddleocr.py:760, in PaddleOCR.ocr(self, img, det, rec, cls, bin, inv, alpha_color, slice)
#     758 for img in imgs:
#     759     img = preprocess_image(img)
# --> 760     dt_boxes, rec_res, _ = self.__call__(img, cls, slice)
#     761     if not dt_boxes and not rec_res:
#     762         ocr_res.append(None)
#
# File /opt/conda/envs/qwen/lib/python3.9/site-packages/paddleocr/tools/infer/predict_system.py:109, in TextSystem.__call__(self, img, cls, slice)
#     107     elapse = sum(elapsed)
#     108 else:
# --> 109     dt_boxes, elapse = self.text_detector(img)
#     111 time_dict["det"] = elapse
#     113 if dt_boxes is None:
#
# File /opt/conda/envs/qwen/lib/python3.9/site-packages/paddleocr/tools/infer/predict_det.py:396, in TextDetector.__call__(self, img, use_slice)
#     394         elapse += sub_elapse
#     395 else:
# --> 396     dt_boxes, elapse = self.predict(img)
#     397 return dt_boxes, elapse
#
# File /opt/conda/envs/qwen/lib/python3.9/site-packages/paddleocr/tools/infer/predict_det.py:231, in TextDetector.predict(self, img)
#     230 def predict(self, img):
# --> 231     ori_im = img.copy()
#     232     data = {"image": img}
#     234     st = time.time()
#
# KeyboardInterrupt:

# %%
key_words=json.load(open('/home/pubw/proj/UserIntent/utils/task2_text_frequency_top20.json'))
key_words = [item for sublist in list(key_words.values()) for item in sublist]

# %%
key_words
# Out:
# ['退款',
#  '退货',
#  '商家',
#  '服务',
#  '裹',
#  '寄件',
#  '申请',
#  '地址',
#  '运费',
#  '上门',
#  '商品',
#  '详情',
#  '快递',
#  '菜鸟',
#  '联系',
#  '信息',
#  '修改',
#  '成功',
#  '全部',
#  '员',
#  '服务',
#  '保障',
#  '产品',
#  'Apple',
#  '保修',
#  '范围',
#  '你',
#  'Charging',
#  '有限',
#  '到期',
#  '日期',
#  '硬件',
#  '聊天',
#  '支持',
#  '权益',
#  '我们',
#  '提供',
#  '对',
#  'AppleCare',
#  '提出',
#  '宝贝',
#  '店铺',
#  '付款',
#  '新品',
#  '服务',
#  '粉丝',
#  '客服',
#  '榜',
#  '推荐',
#  '分类',
#  '体验',
#  '首页',
#  '关注',
#  '综合',
#  '保障',
#  'HOT',
#  '销量',
#  '感兴趣',
#  '满',
#  '晒单',
#  '运费',
#  '元',
#  '支付',
#  '订单',
#  '裹',
#  '快递',
#  '费用',
#  '优惠',
#  '价格',
#  '计费',
#  '详情',
#  '菜鸟',
#  '运输',
#  '退货',
#  '重量',
#  '件',
#  '明细',
#  '险',
#  'kg',
#  '退款',
#  '元',
#  '可用',
#  '满',
#  '券',
#  '红包',
#  '抢',
#  '立即',
#  '使用',
#  '天猫',
#  '消费',
#  '专享',
#  '领取',
#  '实付',
#  '优惠',
#  '商品',
#  '数码',
#  '惊喜',
#  '限量',
#  '兑换',
#  '减',
#  '物流',
#  '异常',
#  '快件',
#  '提醒',
#  '包裹',
#  '卖家',
#  '复制',
#  '详细信息',
#  '客服',
#  '打电话',
#  '联系',
#  '信息',
#  '温馨',
#  '提示',
#  '等待',
#  '查看',
#  '订单',
#  '耐心',
#  '退款',
#  '处理',
#  '元',
#  '运费',
#  '退货',
#  '可用',
#  '包',
#  '红包',
#  '满',
#  '评价',
#  '险',
#  '自动',
#  '退',
#  '详情',
#  '权益',
#  '后',
#  '开通',
#  '商品',
#  '补贴',
#  '卡',
#  '选择',
#  '专享',
#  '投诉',
#  '卖家',
#  '处理',
#  '发货',
#  '平台',
#  '客服',
#  '问题',
#  '完成',
#  '详情',
#  '发起',
#  '原因',
#  '判决',
#  '专属',
#  '元',
#  '举报',
#  '进度',
#  '赔付',
#  '物流',
#  '耐心',
#  '虚假',
#  '换货',
#  '商品',
#  '卖家',
#  '颜色',
#  '分类',
#  '详情',
#  '申请',
#  '新',
#  '协商',
#  '历史',
#  '信息',
#  '原',
#  '发货',
#  '全部',
#  '客服',
#  '平台',
#  '关闭',
#  '并',
#  '查看',
#  '确认',
#  '补贴',
#  '购买',
#  '元',
#  '服务',
#  '立即',
#  '天猫',
#  '发货',
#  '百亿',
#  '件',
#  '限购',
#  '有',
#  '货',
#  '后',
#  '缺货',
#  '钛',
#  '金属',
#  '已选',
#  '保障',
#  '颜色',
#  '更',
#  '元',
#  '可用',
#  '满',
#  '抢',
#  '红包',
#  '立即',
#  '现金',
#  '券',
#  '兑换',
#  '领',
#  '限量',
#  '淘宝',
#  '领取',
#  '通用',
#  '签到',
#  '元宝',
#  '惊喜',
#  '补贴',
#  '更',
#  '奖励',
#  '补贴',
#  '元',
#  '百亿',
#  '客服',
#  '购买',
#  '发货',
#  '运费',
#  '店铺',
#  '前',
#  '减',
#  '正品',
#  '收藏',
#  '立即',
#  '优惠',
#  '购物车',
#  '已售',
#  '全网',
#  '售后',
#  '无忧',
#  '低价',
#  '快递',
#  '快件',
#  '服务',
#  '支付',
#  '签收',
#  '元',
#  '更',
#  '补贴',
#  '官方',
#  '有',
#  '呼出',
#  '秒',
#  '信息',
#  '立即',
#  '分拣',
#  '中心',
#  '多',
#  '寄',
#  '时间',
#  '到达',
#  '快件',
#  '包裹',
#  '运输',
#  '复制',
#  '快递',
#  '联系',
#  '客服',
#  '打电话',
#  '到达',
#  '中心',
#  '物流',
#  '查看',
#  '订阅',
#  '收',
#  '订单',
#  '卖家',
#  '详细信息',
#  '派送',
#  '信息',
#  '转运',
#  '减',
#  '每',
#  '跨店',
#  '满减',
#  '件',
#  '价格',
#  '波动',
#  '购物车',
#  '红包',
#  '券后',
#  '合计',
#  '明细',
#  '凑单',
#  '满',
#  '管理',
#  '已选',
#  '结算',
#  '共减',
#  '淘宝',
#  '每满',
#  '退款',
#  '申请',
#  '退货',
#  '成功',
#  '详情',
#  '金额',
#  '服务',
#  '售后',
#  '红包',
#  '运费',
#  '待',
#  '信息',
#  '取件',
#  '卖家',
#  '原因',
#  '联系',
#  '发货',
#  '上门',
#  '时间',
#  '买家',
#  '平台',
#  '处理',
#  '客服',
#  '卖家',
#  '发货',
#  '退款',
#  '取件',
#  '进度',
#  '介入',
#  '上门',
#  '小时',
#  '保障',
#  '问题',
#  '详情',
#  '核实',
#  '申请',
#  '服务',
#  '联系',
#  '预计',
#  '通知',
#  '元',
#  '卡',
#  '规则',
#  '天猫',
#  '发票',
#  '退款',
#  '服务',
#  '发货',
#  '申请',
#  '查看',
#  '商家',
#  '退货',
#  '消息',
#  '官方',
#  '商品',
#  '减',
#  '运费',
#  '保障',
#  '宝贝',
#  '权益',
#  '交易',
#  '付款',
#  '订单',
#  '发货',
#  '时间',
#  '查看',
#  '实',
#  '更',
#  '多',
#  '天无',
#  '理由',
#  '卖家',
#  '收货',
#  '运费',
#  '时',
#  '号',
#  '信息',
#  '服务',
#  '退款',
#  '退货',
#  '评价',
#  '好',
#  '非常',
#  '很',
#  '追评',
#  '颜色',
#  '评论',
#  '尺码',
#  '浏览',
#  '分类',
#  '有',
#  '写',
#  '全部',
#  '点赞',
#  '推荐',
#  '待',
#  '还',
#  '物流',
#  '发布',
#  '合适',
#  '元',
#  '账单',
#  '零钱',
#  '红包',
#  '淘宝',
#  '记录',
#  '发放',
#  '提现',
#  '购物',
#  '使用',
#  '金',
#  '退款',
#  '查看',
#  '充',
#  '详情',
#  '关联',
#  '支付',
#  '充值',
#  '时间',
#  '元宝',
#  '待',
#  '快递',
#  '签收',
#  '裹',
#  '物流',
#  '查看',
#  '收货',
#  '订单',
#  '取件',
#  '菜鸟',
#  '包裹',
#  '点击',
#  '详情',
#  '信息',
#  '寄',
#  '购买',
#  '寄件',
#  '元',
#  '商品',
#  '为您服务',
#  '购买',
#  '失败',
#  '知道',
#  '订单',
#  '下单',
#  '同一时间',
#  '人数',
#  '过多',
#  '建议您',
#  '稍后',
#  '快递',
#  '服务',
#  '确认',
#  '极速',
#  '退款',
#  '优惠',
#  '发货',
#  '天无',
#  '理由',
#  '包邮送']

# %%
def mask_and_fill_with_external_values(image_path, polygons, output_path="output.jpg"):
    """
    使用多边形区域外部值填充多边形区域。
    
    :param image_path: 输入图片路径。
    :param polygons: 多边形坐标列表，例如 [[[x1, y1], [x2, y2], ...], ...]
    :param output_path: 输出图片路径。
    """
    # 1. 读取图片
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError("无法加载图片，请检查路径是否正确。")
    
    # 2. 创建掩膜
    mask = np.zeros(image.shape[:2], dtype=np.uint8)
    for polygon_coords in polygons:
        polygon_coords = np.array([polygon_coords], dtype=np.int32)
        cv2.fillPoly(mask, polygon_coords, 255)
    
    # 3. 使用掩膜外部值进行填充
    result = cv2.inpaint(image, mask, inpaintRadius=3, flags=cv2.INPAINT_TELEA)
    
    # 4. 保存结果
    cv2.imwrite(output_path, result)
    return result

# 示例用法
coords_list = [
    [[352, 1402], [728, 1402], [728, 1445], [352, 1445]],
    [[100, 200], [150, 200], [150, 250], [100, 250]]
]
# 示例用法
coords = [[352.0, 1402.0], [728.0, 1402.0], [728.0, 1445.0], [352.0, 1445.0]]
image_path = "/home/pubw/datasets/www25/train/images/8e745837-7749-4f39-afd0-82f7977ded8d-2074-0.jpg"  # 输入图片路径
output_path = "output.jpg"  # 输出图片路径

# 调用函数
blurred_image = mask_and_fill_with_external_values(image_path, coords_list, output_path=output_path)

# %%
import json
import os
from PIL import Image

from tqdm import tqdm

import torch
import logging
import jieba


# 设置基本配置，level=logging.WARNING表示只记录warning及更高级别的日志
logging.getLogger('ppocr').setLevel(logging.ERROR)
train_json="/home/pubw/datasets/www25/train/train_task2.json"
image_path="/home/pubw/datasets/www25/train/images/"
save_path="/home/pubw/proj/UserIntent/masked/all/"
os.makedirs(save_path, exist_ok=True)
json_file=json.load(open(train_json))


word_list={}
image_info_list=[]

for item in tqdm(json_file):
    if item['output'] not in word_list:
        word_list[item['output']]=[]
    image_list=[image_path+item_path for item_path in item['image']]
    input_image_list=[]
    #for image_item in image_list:
        #input_image_list.append(Image.open(image_path+image_item).convert('RGB'))
    
    for img in image_list:
        mask_list=[]
        ocr_res=ocr_model.ocr(img, cls=False)[0]
        if ocr_res is None:
            continue
        for ocr_tiem in ocr_res:
            #print(ocr_tiem)
            #print(f"bbox:{ocr_tiem[0]},res:{ocr_tiem[1]}")
            #TODO: 关键词筛选
            mask_list.append(ocr_tiem[0])
            word_list[item['output']].extend(jieba.lcut(ocr_tiem[1]))
        #mask_and_fill_with_external_values(img,mask_list,save_path+img.split("/")[-1])
